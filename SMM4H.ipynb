# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive  -o nonempty

# %%
# !wget https://storage.googleapis.com/bert_models/2018_10_18/cased_L-12_H-768_A-12.zip
# Out:
# --2021-07-01 19:53:10--  https://storage.googleapis.com/bert_models/2018_10_18/cased_L-12_H-768_A-12.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.119.128, 108.177.126.128, 108.177.127.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.119.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 404261442 (386M) [application/zip]
# Saving to: ‘cased_L-12_H-768_A-12.zip’
#
# cased_L-12_H-768_A- 100%[===================>] 385.53M  96.1MB/s    in 4.0s
#
# 2021-07-01 19:53:14 (96.1 MB/s) - ‘cased_L-12_H-768_A-12.zip’ saved [404261442/404261442]

# %%
# !unzip /content/cased_L-12_H-768_A-12.zip
# Out:
# Archive:  /content/cased_L-12_H-768_A-12.zip
#    creating: cased_L-12_H-768_A-12/
#   inflating: cased_L-12_H-768_A-12/bert_model.ckpt.meta
#   inflating: cased_L-12_H-768_A-12/bert_model.ckpt.data-00000-of-00001
#   inflating: cased_L-12_H-768_A-12/vocab.txt
#   inflating: cased_L-12_H-768_A-12/bert_model.ckpt.index
#   inflating: cased_L-12_H-768_A-12/bert_config.json

# %%
# !wget https://github.com/google-research/bert

# %%
# !pwd
# Out:
# /content

# %%
# !git clone https://github.com/google-research/bert.git

# %%
# !cd bert/
# !pwd
# !ls
# Out:
# /content
# adc.json  cased_L-12_H-768_A-12      drive
# bert	  cased_L-12_H-768_A-12.zip  sample_data

# %%
import os
os.chdir('/content/bert')

# %%
# !pip install tensorflow-gpu==1.15.0

# %%
# !python run_classifier.py \
  --task_name=MRPC \
  --do_train=true \
  --do_eval=true \
  --data_dir=$GLUE_DIR/MRPC \
  --vocab_file=/content/cased_L-12_H-768_A-12/vocab.txt \
  --bert_config_file=/content/cased_L-12_H-768_A-12/bert_config.json \
  --init_checkpoint=/content/cased_L-12_H-768_A-12/bert_model.ckpt.data-00000-of-00001 \
  --do_lower_case=False  \
  --max_seq_length=128 \
  --train_batch_size=32 \
  --learning_rate=2e-5 \
  --num_train_epochs=3.0 \
  --output_dir=/tmp/mrpc_output/

# %%
# !git clone https://github.com/facebookresearch/SpanBERT.git
# Out:
# Cloning into 'SpanBERT'...
# remote: Enumerating objects: 267, done.
# remote: Total 267 (delta 0), reused 0 (delta 0), pack-reused 267
# Receiving objects: 100% (267/267), 365.95 KiB | 17.43 MiB/s, done.
# Resolving deltas: 100% (154/154), done.

# %%
# !pwd
#!unzip /content/Subtask1b.zip
# !cd /content/
# !pwd
# !unzip /content/Subtask1b.zip

# %%
# !cd /content/
# !pwd
# Out:
# /content/bert

# %%
# !cp -r /content/bert/SpanBERT /content/

# %%
# !rm -rf /content/bert/SpanBERT

# %%
# !cp -r /content/bert/Subtask1b /content/
# !rm -rf /content/bert/Subtask1b

# %%
# !wget https://dl.fbaipublicfiles.com/fairseq/models/spanbert_hf_base.tar.gz
# Out:
# --2021-02-15 22:44:13--  https://dl.fbaipublicfiles.com/fairseq/models/spanbert_hf_base.tar.gz
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.74.142, 104.22.75.142, 172.67.9.4, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 198960653 (190M) [application/gzip]
# Saving to: ‘spanbert_hf_base.tar.gz’
#
# spanbert_hf_base.ta 100%[===================>] 189.74M  27.3MB/s    in 7.5s
#
# 2021-02-15 22:44:21 (25.4 MB/s) - ‘spanbert_hf_base.tar.gz’ saved [198960653/198960653]

# %%
# !unzip /content/spanbert_hf_base1.tar.gz
# Out:
# unzip:  cannot find or open /content/spanbert_hf_base1.tar.gz, /content/spanbert_hf_base1.tar.gz.zip or /content/spanbert_hf_base1.tar.gz.ZIP.

# %%
# !cp -r /content/bert/spanbert_hf_base.tar.gz /content/
# !rm -rf /content/bert/spanbert_hf_base.tar.gz

# %%
# !rm -rf /content/bert/Task1-DataForParticipants

# %%
# !pip install boto3

# %%
# !wget https://github.com/nate-parrott/squad/blob/master/data/dev-v1.1.json
# Out:
# --2021-02-15 23:46:51--  https://github.com/nate-parrott/squad/blob/master/data/dev-v1.1.json
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘dev-v1.1.json’
#
# dev-v1.1.json           [ <=>                ]  91.43K  --.-KB/s    in 0.005s
#
# 2021-02-15 23:46:52 (17.2 MB/s) - ‘dev-v1.1.json’ saved [93621]

# %%
# !wget https://github.com/nate-parrott/squad/blob/master/data/train-v1.1.json
# Out:
# --2021-02-15 23:47:22--  https://github.com/nate-parrott/squad/blob/master/data/train-v1.1.json
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘train-v1.1.json’
#
# train-v1.1.json         [ <=>                ]  91.47K  --.-KB/s    in 0.007s
#
# 2021-02-15 23:47:23 (12.9 MB/s) - ‘train-v1.1.json’ saved [93665]

# %%
# !git clone https://github.com/NVIDIA/apex
# %cd apex
# !pip install -v --no-cache-dir --global-option="--pyprof" --global-option="--cpp_ext" --global-option="--cuda_ext" ./

# %%
# %cd /content
# !rm -rf /content/apex
# Out:
# /content

# %%
# !git clone https://github.com/NVIDIA/apex.git
#!pip uninstall apex
# %cd apex
# !pwd
# !pip install -v --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./

# %%
# !pip install https://github.com/NVIDIA/apex

# %%
# %cd /content/
# Out:
# /content

# %%
# !git clone https://github.com/NVIDIA/apex
# !pip install setup.py

# %%
# !cp -r /content/apex /content/SpanBERT
# Out:
# cp: cannot stat '/content/apex': No such file or directory

# %%
# !python /content/SpanBERT/code/run_squad.py \
  --do_train \
  --do_eval \
  --eval_test \
  --model spanbert-base-cased \
  --train_file train-tmp1-v1.1.json \
  --dev_file dev-tmp-v1.1.json \
  --test_file test-tmp-v1.1.json \
  --train_batch_size 32 \
  --eval_batch_size 32  \
  --learning_rate 2e-5 \
  --num_train_epochs 1 \
  --max_seq_length 256 \
  --doc_stride 128 \
  --eval_metric f1 \
  --output_dir squad_output1 \
  --fp16

# %%
# !rm -rf /content/squad_output1

# %%
# !python -c 'from apex.optimizers import FusedAdam'

# %%
# !unzip /content/Subtask1b.zip
# Out:
# Archive:  /content/Subtask1b.zip
#    creating: Subtask 1b/
#    creating: Subtask 1b/training/
#   inflating: Subtask 1b/training/train_spans.tsv
#   inflating: Subtask 1b/training/train_tweets.tsv
#    creating: Subtask 1b/validation/
#   inflating: Subtask 1b/validation/spans.tsv
#   inflating: Subtask 1b/validation/tweets.tsv

# %%
# !git clone https://github.com/huggingface/transformers
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 80876, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 80876 (delta 47), reused 66 (delta 26), pack-reused 80770
# Receiving objects: 100% (80876/80876), 63.13 MiB | 23.12 MiB/s, done.
# Resolving deltas: 100% (57898/57898), done.

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 2.6 MB 5.0 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 35.4 MB/s
# ...
#      |████████████████████████████████| 895 kB 65.4 MB/s
# ...
#      |████████████████████████████████| 636 kB 59.3 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("dmis-lab/biobert-v1.1")
model = AutoModelForTokenClassification.from_pretrained("dmis-lab/biobert-v1.1")

nlp = pipeline("ner", model=model, tokenizer=tokenizer)
#example = "My name is Wolfgang and I live in Berlin"
example = "do you have any medication allergies?"

ner_results = nlp(example)
print(ner_results)

# %%
# !pip install git+https://www.github.com/bojone/bert4keras.git

# %%
# !git clone https://github.com/bojone/bert4keras
# Out:
# Cloning into 'bert4keras'...
# remote: Enumerating objects: 6670, done.
# remote: Total 6670 (delta 0), reused 0 (delta 0), pack-reused 6670
# Receiving objects: 100% (6670/6670), 9.58 MiB | 14.24 MiB/s, done.
# Resolving deltas: 100% (4437/4437), done.

# %%
# !pip install --upgrade keras<=2.3.1
# Out:
# /bin/bash: =2.3.1: No such file or directory

# %%
# !pip uninstall tensorflow
# !rm -rf ~/anaconda3/lib/python3.6/site-packages/tensorflow
# !pip install tensorflow

# %%
# !python /content/bert4keras/examples/task_sequence_labeling_ner_crf.py
# Out:
# 2021-02-17 02:37:40.699114: W tensorflow/stream_executor/platform/default/dso_loader.cc:60] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2021-02-17 02:37:40.699189: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# Traceback (most recent call last):
#   File "/content/bert4keras/examples/task_sequence_labeling_ner_crf.py", line 8, in <module>
#     from bert4keras.models import build_transformer_model
#   File "/usr/local/lib/python3.6/dist-packages/bert4keras/models.py", line 5, in <module>
#     from bert4keras.layers import *
#   File "/usr/local/lib/python3.6/dist-packages/bert4keras/layers.py", line 97, in <module>
#     NodeBase = keras.engine.base_layer.Node
# AttributeError: module 'keras.engine.base_layer' has no attribute 'Node'

# %% [markdown]
# ehr-relation-extraction

# %%
# !git clone https://github.com/smitkiri/ehr-relation-extraction
# Out:
# Cloning into 'ehr-relation-extraction'...
# remote: Enumerating objects: 688, done.
# remote: Counting objects: 100% (320/320), done.
# remote: Compressing objects: 100% (228/228), done.
# remote: Total 688 (delta 190), reused 212 (delta 92), pack-reused 368
# Receiving objects: 100% (688/688), 1.14 MiB | 5.73 MiB/s, done.
# Resolving deltas: 100% (398/398), done.

# %%
# !pip install data_processor
# Out:
# ERROR: Could not find a version that satisfies the requirement data_processor (from versions: none)
# ERROR: No matching distribution found for data_processor

# %%
# %cd /content/
# !pwd
# Out:
# /content
# /content

# %% [markdown]
# 需要先!pip install transformers
#
# comment掉re的部分

# %%
# !python /content/ehr-relation-extraction/generate_data.py \
    --task ner \
    --input_dir data1/ \
    --target_dir dataset/ \
    --max_seq_len 256 \
    --dev_split 0.1 \
    --tokenizer biobert-base \
    --ext txt \
    --sep " " \

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !rm -r /content/ehr-relation-extraction

# %%
# !pip install seqeval

# %%
# !pip install ehr
# Out:
# ERROR: Could not find a version that satisfies the requirement ehr (from versions: none)
# ERROR: No matching distribution found for ehr

# %%
# !python /content/ehr-relation-extraction/biobert_ner/run_ner.py
# Out:
# Traceback (most recent call last):
#   File "/content/ehr-relation-extraction/biobert_ner/run_ner.py", line 9, in <module>
#     from seqeval.metrics import f1_score, precision_score, recall_score
# ModuleNotFoundError: No module named 'seqeval'

# %%
# %cd ehr-relation-extraction/
# Out:
# /content/ehr-relation-extraction

# %%
# !pwd
# Out:
# /content/ehr-relation-extraction

# %%
# %cd /content/
# Out:
# /content

# %%
# !rm -rf /content/dataset

# %%
# !rm -rf /content/output

# %%
# !export SAVE_DIR=./output
# !export DATA_DIR=./dataset

# !export MAX_LENGTH=128
# !export BATCH_SIZE=16
# !export NUM_EPOCHS=1
# !export SAVE_STEPS=1000000
# !export SEED=0

# !python /content/ehr-relation-extraction/biobert_ner/run_ner.py \
    --data_dir /content/dataset/ \
    --labels /content/dataset/labels.txt \
    --model_name_or_path dmis-lab/biobert-base-cased-v1.1 \
    --output_dir /content/output/ \
    --max_seq_length 128 \
    --num_train_epochs 1 \
    --per_device_train_batch_size 16 \
    --save_steps 1000000 \
    --seed 0 \
    --do_train \
    --do_eval \
    --do_predict \
    --overwrite_output_dir

# %%
# !ls
# !tar zcvf dataset_only_train_balance1.tar.gz dataset_only_train_balance1/
# Out:
# data1			     spans.tsv		   train_spans.tsv
# dataset_only_train_balance1  submit.tsv		   train_tweets.tsv
# ehr-relation-extraction      test_order.txt	   tweets.tsv
# sample_data		     test_predictions.txt
# dataset_only_train_balance1/
# dataset_only_train_balance1/test.pkl
# dataset_only_train_balance1/devel.pkl
# dataset_only_train_balance1/train_dev.pkl
# dataset_only_train_balance1/train.pkl
# dataset_only_train_balance1/train.txt
# dataset_only_train_balance1/devel.txt
# dataset_only_train_balance1/test.txt
# dataset_only_train_balance1/labels.txt
# dataset_only_train_balance1/train_dev.txt

# %%
# !cp /content/ehr-relation-extraction/ehr.py /content/ehr-relation-extraction/biobert_ner
# !cp /content/ehr-relation-extraction/annotations.py /content/ehr-relation-extraction/biobert_ner

# %%
# %cd /content/
# Out:
# /content

# %%
# !mkdir data1
# %cd data1
# !mkdir train
# !mkdir test
# Out:
# /content/data1

# %% [markdown]
# 对文本做处理

# %%
# !rm -rf /content/data1/test/
#!rm -rf /content/data2

# %%
# %cd data1
# !mkdir test
# Out:
# /content/data1

# %% [markdown]
# 先做train.txt 和 test.txt

# %%
# !pip3 install emoji

# %%
# !pip install emoji
# Out:
# ...
#      |████████████████████████████████| 133kB 5.6MB/s
# ...

# %%
import csv
import os
#import emoji
import re
import emoji

path = "/content/train_tweets.tsv"
wpath = "/content/data1/train/"
#path = "/content/tweets.tsv"
#wpath = "/content/data1/test/"
#path = "/content/test_tweets.tsv"

with open(path,'r',encoding='utf-8') as tsvin:
  tsvin = csv.reader(tsvin, delimiter='\t')
  for line in tsvin:
    #if(line[1][0]=="\""):

      #print(line[1])
    #if(line[0]=='332540699692130304'):
      #print(line[1].replace(" ","\n"))
    #line_1 = emoji.demojize(line[1])
    line_1 = re.sub(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b', '', line[1], flags=re.MULTILINE)
    line_1 = emoji.demojize(line_1)
    #line_1 = re.sub(r'[^A-Za-z0-9 ]+', '', result)
    #print(line[0],line_1)
    line_1 = re.sub(r'[^A-Za-z0-9 @_:"!,.#()/%~&*\-\']+', '', line_1)
    new_line = line_1.replace(" ","\n")
    #print(new_line)
    if(new_line[0]=='\n'):
        new_line = new_line[1:]
        #print(new_line)
    with open(wpath + line[0] + ".txt",'w') as wf:
      wf.write(new_line)

# %% [markdown]
# 再做train.ann和test.ann

# %%
import csv
import os

path = "/content/train_spans.tsv"
wpath = "/content/data1/train/"
#path = "/content/spans.tsv"
#wpath = "/content/data1/test/"
#path = "/content/test_tweets.tsv"

with open(path,'r',encoding='utf-8') as tsvin:
  tsvin = csv.reader(tsvin, delimiter='\t')
  for line in tsvin:
    #print(line)
    #print(line[0]+"\t"+line[1]+" "+line[2]+";"+line[3]+"\t"+line[4])
    new_line = line[0]+"\t"+line[1]+" "+line[2]+";"+line[3]+"\t"+line[4]
    with open(wpath + line[0] + ".ann",'a') as wf:
      wf.write(new_line + '\n')

# %% [markdown]
# 给没有任何ADE的文章建立ann

# %%
import os
filePath = "/content/data1/test/"
#filePath = "/content/data1/train/"
os.listdir(filePath)
filelist = os.listdir(filePath)
def findSubStr01(substr, str):
    i=1
    while i > 0:
        index = str.find(substr)   #第一次出现的位置
        #index2=str.find(substr,index+1)  #第二次出现的位置
        #index3=str.find(substr,index2+1)  #第三次出现的位置
        #print(index)
        #print(index2)
        #print(index3)
        i-=1
    return index

for file in filelist:
  """if file.endswith(".txt"):
    index = findSubStr01(".txt",file)
    #print(index)
    #print(file[:index+1])
    with open(filePath + file[:index] + ".ann",'w') as wf:
      wf.write("#")"""
  if file.endswith(".txt") and os.path.isfile(filePath + file[:18] + ".ann")==False:
    #print(os.path.isfile(filePath + file[:18] + ".ann"))
    #print(file[:18]+".ann")
    with open(filePath + file[:18] + ".ann",'w') as wf:
      wf.write("#")

# %%
with open(filePath + file[:18] + ".ann",'w') as wf:
      wf.write("#")

# %%
import emoji
filePath = "/content/data1/test/"
os.listdir(filePath)
filelist = os.listdir(filePath)
for file in filelist:
  with open(filePath+file,'r')

# %%
import csv
import os
import re
import emoji

path = "/content/train_tweets.tsv"
#wpath = "/content/data1/train/"

with open(path,'r',encoding='utf-8') as tsvin:
  tsvin = csv.reader(tsvin, delimiter='\t')
  for line in tsvin:
    #if(line[1][0]=="\""):

    #print(line[1])
    if(line[0]=='332317478170546176'):
      print(line[1])
      line_1 = re.sub(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b', '', line[1], flags=re.MULTILINE)
      line_1 = emoji.demojize(line_1)
      #line_1 =
      print(line_1)
      line_1 = re.sub(r'[^A-Za-z0-9 @_:"!,.#()/%~&*\-\']+', '', line_1)
      #line_1 = line_1.replace("   "," ")
      #line_1 = line_1.replace("  "," ")

      new_line = line_1.replace(" ","\n")
      if(new_line[0]=='\n'):
        new_line = new_line[1:]
      print(new_line)

# %%
path = "/content/data1/train/340556379175661568.txt"
with open(path,'r') as f:
  for line in f:
    print(line)

# %%
# !rm "/content/data1/train/326453069795688449.txt"
# !rm "/content/data1/train/326453069795688449.ann"
# !rm "/content/data1/train/342045662206119937.txt"
# !rm "/content/data1/train/342045662206119937.ann"
# !rm "/content/data1/train/331388935186051073.txt"
# !rm "/content/data1/train/331388935186051073.ann"
# !rm "/content/data1/train/347318146572627968.txt"
# !rm "/content/data1/train/347318146572627968.ann"
# !rm "/content/data1/train/340556343473762304.txt"
# !rm "/content/data1/train/340556343473762304.ann"
# Out:
# rm: cannot remove '/content/data1/train/326453069795688449.txt': No such file or directory
# rm: cannot remove '/content/data1/train/326453069795688449.ann': No such file or directory
# rm: cannot remove '/content/data1/train/342045662206119937.txt': No such file or directory
# rm: cannot remove '/content/data1/train/342045662206119937.ann': No such file or directory
# rm: cannot remove '/content/data1/train/331388935186051073.txt': No such file or directory
# rm: cannot remove '/content/data1/train/331388935186051073.ann': No such file or directory
# rm: cannot remove '/content/data1/train/347318146572627968.txt': No such file or directory
# rm: cannot remove '/content/data1/train/347318146572627968.ann': No such file or directory
# rm: cannot remove '/content/data1/train/340556343473762304.txt': No such file or directory
# rm: cannot remove '/content/data1/train/340556343473762304.ann': No such file or directory

# %%
# !rm "/content/data1/train/535183640381382656.txt"
# !rm "/content/data1/train/535183640381382656.ann"

# %%
# !rm "/content/data1/train/508118591913205761.txt"
# !rm "/content/data1/train/508118591913205761.ann"
# Out:
# rm: cannot remove '/content/data1/train/508118591913205761.txt': No such file or directory
# rm: cannot remove '/content/data1/train/508118591913205761.ann': No such file or directory

# %%
# !rm "/content/data1/train/464341006499201024.txt"
# !rm "/content/data1/train/464341006499201024.ann"

# %%
#326453069795688449
#342045662206119937
#331388935186051073
#347318146572627968
#340556343473762304

# %%
# %cd /content/
# Out:
# /content

# %%
# !rm -r /content/dataset_vote1/

# %%
# !mkdir /content/dataset_vote1/

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 2.6 MB 4.1 MB/s
# ...
#      |████████████████████████████████| 636 kB 48.0 MB/s
# ...
#      |████████████████████████████████| 895 kB 48.1 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 46.5 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %% [markdown]
# labels要改掉

# %%
# !python /content/ehr-relation-extraction/generate_data.py \
    --task ner \
    --input_dir data1/ \
    --target_dir dataset_n2c2_1shot/ \
    --max_seq_len 256 \
    --dev_split 0.1 \
    --tokenizer biobert-base \
    --ext txt \
    --sep " " \
# Out:
# Reading data
#
# Train data:
# Progress: [====================] 18/18
#
# Test Data:
# Progress: [====================] 12827/12827
#
# Data successfully saved in dataset_n2c2_1shot/train.txt
# Variable successfully saved in dataset_n2c2_1shot/train.pkl
# Data successfully saved in dataset_n2c2_1shot/train_dev.txt
# Variable successfully saved in dataset_n2c2_1shot/train_dev.pkl
# Data successfully saved in dataset_n2c2_1shot/devel.txt
# Variable successfully saved in dataset_n2c2_1shot/devel.pkl
# Data successfully saved in dataset_n2c2_1shot/test.txt
# Variable successfully saved in dataset_n2c2_1shot/test.pkl
#
# Generating files successful. Files generated: train.txt, train.pkl, train_dev.txt, train_dev.pkl, devel.txt, devel.pkl, test.txt, test.pkl, labels.txt

# %%
# !rm -r /content/data1

# %%
# !unzip /content/ehr_format.zip

# %%
# !tar zcvf dataset_n2c2_1shot.tar.gz dataset_n2c2_1shot/
# Out:
# dataset_n2c2_1shot/
# dataset_n2c2_1shot/test.txt
# dataset_n2c2_1shot/devel.txt
# dataset_n2c2_1shot/train_dev.pkl
# dataset_n2c2_1shot/test.pkl
# dataset_n2c2_1shot/labels.txt
# dataset_n2c2_1shot/devel.pkl
# dataset_n2c2_1shot/train.pkl
# dataset_n2c2_1shot/train_dev.txt
# dataset_n2c2_1shot/train.txt

# %%
# !zip /content/ehr-relation-extraction
# Out:
# zip error: Nothing to do! (/content/ehr-relation-extraction.zip)

# %%
# !tar xzvf /content/dataset_bertlarge.tar.gz
# Out:
# dataset_bertlarge/
# dataset_bertlarge/labels.txt
# dataset_bertlarge/train.txt
# dataset_bertlarge/train_dev.txt
# dataset_bertlarge/test.pkl
# dataset_bertlarge/devel.txt
# dataset_bertlarge/train.pkl
# dataset_bertlarge/train_dev.pkl
# dataset_bertlarge/devel.pkl
# dataset_bertlarge/test.txt

# %%
看一下testdata有多少条，应该是1w左右 10908

# %%
path = '/content/test_tweets.tsv'


with open(path,'r') as f:

  tsvin = csv.reader(f, delimiter='\t')
  count = 0
  for line in tsvin:
    count+=1
print(count)
# Out:
# 10908

# %% [markdown]
# randomly选一些negative doc

# %%
filePath = "/content/data1/train"
#filePath = "/content/data1/test"
import os
import csv
import re
import emoji
os.listdir(filePath)
filelist = os.listdir(filePath)

file_pos_list = set()
for file in filelist:
  file_pos_list.add(file[:18])
print(file_pos_list)
print(len(file_pos_list))

import random
#L=[random.randint(0,2000) for _ in range(17385)]
#print(L)

path = "/content/train_tweets.tsv"
wpath = "/content/data1/train/"
#path = "/content/tweets.tsv"
#wpath = "/content/data1/test/"

file_neg_list = set()
with open(path,'r',encoding='utf-8') as tsvin:
  tsvin = csv.reader(tsvin, delimiter='\t')
  for line in tsvin:
    if(line[0] not in file_pos_list):
      file_neg_list.add(line[0])
print(file_neg_list)
print(len(file_neg_list))
rand_neg_list = random.sample(file_neg_list,1700)
print(rand_neg_list)
print(len(rand_neg_list))

with open(path,'r',encoding='utf-8') as tsvin:
  tsvin = csv.reader(tsvin, delimiter='\t')
  for line in tsvin:
    if(line[0] in rand_neg_list):
      print(line[0])
      line_1 = re.sub(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b', '', line[1], flags=re.MULTILINE)
      line_1 = emoji.demojize(line_1)
      line_1 = re.sub(r'[^A-Za-z0-9 @_:"!,.#()/%~&*\-\']+', '', line_1)
      new_line = line_1.replace(" ","\n")
      if(new_line[0]=='\n'):
        new_line = new_line[1:]
        #print(new_line)
      with open(wpath + line[0] + ".txt",'w') as wf:
        wf.write(new_line)

# %%
#print(file_neg_list)
#print(len(file_neg_list))
#print(rand_neg_list)
#print(len(rand_neg_list))
remain_neg_list = []
for id in file_neg_list:
  if(id not in rand_neg_list):
    remain_neg_list.append(id)
#print(remain_neg_list)
#print(len(remain_neg_list))

import random
neg_list2 = random.sample(remain_neg_list,1700)
print(neg_list2)
print(len(neg_list2))

remain_neg_list1 = []
for id in remain_neg_list:
  if(id not in neg_list2):
    remain_neg_list1.append(id)
#print(remain_neg_list1)
#print(len(remain_neg_list1))

import random
neg_list3 = random.sample(remain_neg_list1,1700)
print(neg_list3)
print(len(neg_list3))

remain_neg_list2 = []
for id in remain_neg_list1:
  if(id not in neg_list3):
    remain_neg_list2.append(id)
#print(remain_neg_list2)
#print(len(remain_neg_list2))

import random
neg_list4 = random.sample(remain_neg_list2,1700)
print(neg_list4)
print(len(neg_list4))

remain_neg_list3 = []
for id in remain_neg_list2:
  if(id not in neg_list4):
    remain_neg_list3.append(id)
#print(remain_neg_list3)
#print(len(remain_neg_list3))

import random
neg_list5 = random.sample(remain_neg_list3,1700)
print(neg_list5)
print(len(neg_list5))
# Out:
# ['507957900447203328', '466944991743705088', '523272611875528704', '367629487766528000', '352239628956336129', '462859124342935552', '502658471628931072', '467750640006205440', '354293203786141698', '347165351903117312', '506757844947853312', '536885040622604288', '486766757302923264', '348290861785817088', '340575904021487616', '349806983400013825', '349183615537651712', '444575953855844352', '501536059529113600', '331381369735376896', '341713442652188672', '349730622165626880', '510461091499880449', '351732735984926720', '455510087873101824', '327981303863595008', '506146858415423489', '448991795192799232', '490027753517748224', '484278303361355776', '352596679813373953', '342026574062833664', '450986626916052992', '355000430385836032', '336985805283266560', '342116987679428608', '453076932364488704', '492919673290100736', '463326171774877696', '434148019059953664', '344850912461864962', '540730197478477824', '501467107482435584', '344592327798575104', '344628314931068928', '344186
# ...

# %%
path = "/content/train_tweets.tsv"
wpath = "/content/data1/train/"

with open(path,'r',encoding='utf-8') as tsvin:
  tsvin = csv.reader(tsvin, delimiter='\t')
  for line in tsvin:
    if(line[0] in neg_list5):
      print(line[0])
      line_1 = re.sub(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b', '', line[1], flags=re.MULTILINE)
      line_1 = emoji.demojize(line_1)
      line_1 = re.sub(r'[^A-Za-z0-9 @_:"!,.#()/%~&*\-\']+', '', line_1)
      new_line = line_1.replace(" ","\n")
      if(new_line[0]=='\n'):
        new_line = new_line[1:]
        #print(new_line)
      with open(wpath + line[0] + ".txt",'w') as wf:
        wf.write(new_line)

# %% [markdown]
# 把postive的doc先都preprocess好

# %%
filePath = "/content/data1/train"
#filePath = "/content/data1/test"
import os
import csv
import re
import emoji
os.listdir(filePath)
filelist = os.listdir(filePath)

file_pos_list = set()
for file in filelist:
  file_pos_list.add(file[:18])
print(file_pos_list)
print(len(file_pos_list))

path = "/content/train_tweets.tsv"
wpath = "/content/data1/train/"
#path = "/content/tweets.tsv"
#wpath = "/content/data1/test/"

with open(path,'r',encoding='utf-8') as tsvin:
  tsvin = csv.reader(tsvin, delimiter='\t')
  for line in tsvin:
    if(line[0] in file_pos_list):
      print(line[0])
      line_1 = re.sub(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b', '', line[1], flags=re.MULTILINE)
      line_1 = emoji.demojize(line_1)
      line_1 = re.sub(r'[^A-Za-z0-9 @_:"!,.#()/%~&*\-\']+', '', line_1)
      new_line = line_1.replace(" ","\n")
      if(new_line[0]=='\n'):
        new_line = new_line[1:]
        #print(new_line)
      with open(wpath + line[0] + ".txt",'w') as wf:
        wf.write(new_line)

# %%
# !ls
# !tar zcvf dataset_vote1.tar.gz dataset_vote1/
# Out:
# data1			 sample_data	  train_spans.tsv   tweets.tsv
# dataset_vote1		 spans.tsv	  train_tweets.tsv
# ehr-relation-extraction  test_order1.txt  transformers
# dataset_vote1/
# dataset_vote1/labels.txt
# dataset_vote1/train_dev.pkl
# dataset_vote1/test.pkl
# dataset_vote1/train_dev.txt
# dataset_vote1/test.txt
# dataset_vote1/train.txt
# dataset_vote1/train.pkl
# dataset_vote1/devel.txt
# dataset_vote1/devel.pkl

# %%
import csv
import os
#import emoji
import re
import emoji

#path = "/content/train_tweets.tsv"
#wpath = "/content/data1/train/"
path = "/content/tweets.tsv"
wpath = "/content/data1/test/"

with open(path,'r',encoding='utf-8') as tsvin:
  tsvin = csv.reader(tsvin, delimiter='\t')
  for line in tsvin:
    #if(line[1][0]=="\""):

      #print(line[1])
    #if(line[0]=='332540699692130304'):
      #print(line[1].replace(" ","\n"))
    #line_1 = emoji.demojize(line[1])
    line_1 = re.sub(r'(https|http)?:\/\/(\w|\.|\/|\?|\=|\&|\%)*\b', '', line[1], flags=re.MULTILINE)
    line_1 = emoji.demojize(line_1)
    #line_1 = re.sub(r'[^A-Za-z0-9 ]+', '', result)
    #print(line[0],line_1)
    line_1 = re.sub(r'[^A-Za-z0-9 @_:"!,.#()/%~&*\-\']+', '', line_1)
    new_line = line_1.replace(" ","\n")
    #print(new_line)
    if(new_line[0]=='\n'):
        new_line = new_line[1:]
        #print(new_line)
    with open(wpath + line[0] + ".txt",'w') as wf:
      wf.write(new_line)

# %%
# !git clone https://github.com/huggingface/transformers.git
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 62991, done.
# remote: Total 62991 (delta 0), reused 0 (delta 0), pack-reused 62991
# Receiving objects: 100% (62991/62991), 48.00 MiB | 14.61 MiB/s, done.
# Resolving deltas: 100% (44642/44642), done.

# %%
# %cd transformers

# %%
# %cd /content/
# Out:
# /content

# %%
# !pip3 install --upgrade .
# Out:
# ERROR: Directory '.' is not installable. Neither 'setup.py' nor 'pyproject.toml' found.

# %%
# !tar xzvf dataset_only_train_balance1.tar.gz
# Out:
# tar (child): dataset_only_train_balance1.tar.gz: Cannot open: No such file or directory
# tar (child): Error is not recoverable: exiting now
# tar: Child returned status 2
# tar: Error is not recoverable: exiting now

# %%
# !rm -rf /content/transformers/ehr-relation-extraction

# %%
text_list = ['Camp@@', 'bell@@', '\n', 'and@@', '\n', 'the@@', '\n', 'brother@@', 's@@', '\n', 'ta@@', 'king@@', '\n', 'I@@', 'modi@@', 'um@@', '\n', 'like@@', '\n', 'sm@@', 'arti@@', 'es@@', '.']
print(text_list)
new_list = []
for i in range(len(text_list)-1):
  #print(text_list[i])
  if(i==0):
    j = str(text_list[i]).replace("@@","")
    token = j
    new_list.append(token)
  if(i>0 and text_list[i-1]=='\n' and text_list[i+1]=='\n'):
    j = str(text_list[i]).replace("@@","")
    token = j
    new_list.append(token)
  if(i>0 and text_list[i-1]!='\n' and text_list[i+1]=='\n'):
    j = str(text_list[i]).replace("@@","")
    token = "##" + j
    new_list.append(token)
  if(i>0 and text_list[i-1]=='\n' and text_list[i+1]!='\n'):
    j = str(text_list[i]).replace("@@","")
    token = j
    new_list.append(token)
  if(i>0 and text_list[i-1]!='\n' and text_list[i+1]!='\n' and text_list[i]!='\n'):
    j = str(text_list[i]).replace("@@","")
    token = "##" + j
    new_list.append(token)
if(text_list[len(text_list)-2]!='\n'):
  token = "##" + text_list[len(text_list)-1]
  new_list.append(token)
else:
  token = text_list[len(text_list)-1]
  new_list.append(token)
print(new_list)
# Out:
# ['Camp@@', 'bell@@', '\n', 'and@@', '\n', 'the@@', '\n', 'brother@@', 's@@', '\n', 'ta@@', 'king@@', '\n', 'I@@', 'modi@@', 'um@@', '\n', 'like@@', '\n', 'sm@@', 'arti@@', 'es@@', '.']
# ['Camp', '##bell', 'and', 'the', 'brother', '##s', 'ta', '##king', 'I', '##modi', '##um', 'like', 'sm', '##arti', '##es', '##.']

# %%
# !pip install seqeval
# Out:
# ...
#      |████████████████████████████████| 51kB 5.8MB/s
# ...
#   Created wheel for seqeval: filename=seqeval-1.2.2-cp37-none-any.whl size=16172 sha256=07e52e6d1c596cf409cafa855a525aee2aab830b549c5203a0b0059c3d1fbb88
#   Stored in directory: /root/.cache/pip/wheels/52/df/1b/45d75646c37428f7e626214704a0e35bd3cfc32eda37e59e5f
# Successfully built seqeval
# ...

# %%
path = "/content/test.txt"
path1 = "/content/test_predictions4.txt"

test_label = []
test_tmp = []
test_1 = []
with open(path,'r') as f:
  for line in f:
    #if(line=='##\n'):
      #print(line)
      #pred_tmp.append('O')
      #test_1.append('O')
      #continue
    #if(line ==' O\n'):
      #pred_tmp.append('O')
      #test_1.append('O')
      #continue
    if(line!='\n'):
      line = line.strip('\n')
      line = line.split(" ")
      #print(line)
      test_tmp.append(line[1])
      #test_tmp.append('PER')
      test_1.append(line[1])
    if(line=='\n'):
      test_label.append(test_tmp)
      test_tmp = []
print(test_label)

pred_1 = []
pred_label = []
pred_tmp = []
with open(path1,'r') as f1:
  for line in f1:
    #if(line=='##\n'):
      #print(line)
      #continue
    #if(line ==' O\n'):
      #pred_tmp.append('O')
    if(line!='\n'):
      line = line.strip('\n')
      line = line.split(" ")
      #print(line[1])
      pred_tmp.append(line[1])
      #pred_tmp.append('PER')
      pred_1.append(line[1])
    if(line=='\n'):
      pred_label.append(pred_tmp)
      pred_tmp = []
print(pred_label)


from seqeval.metrics import f1_score, precision_score, recall_score, accuracy_score
from seqeval.metrics import classification_report
from seqeval.scheme import IOB2
print(accuracy_score(test_label, pred_label))
print(precision_score(test_label, pred_label))
print(recall_score(test_label, pred_label))
print(f1_score(test_label, pred_label))
print(f1_score(test_label, pred_label, mode='relax'))
#classification_report(test_label, pred_label)

#for i in range(72):
  #test_1.

from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
print(f1_score(test_1,pred_1,average=None))
print(accuracy_score(test_1,pred_1))
print(precision_score(test_1,pred_1,average=None))
print(recall_score(test_1,pred_1,average=None))
# Out:
# [['B-ADE', 'I-ADE', 'I-ADE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 
# ...

# %% [markdown]
# test format

# %%
path = '/content/test_predictions.txt'
from collections import defaultdict

count = 0

pred = defaultdict(list)
with open(path,'r') as f:

  for line in f:
    #tmp = []
    if(line=='\n'):
      count+=1
      #print(count)
    if(line!='\n'):
      line = line.strip('\n')
      line = line.split(" ")
      if(line[1]!='O'):
        #print(line[0], line[1])
        #print(count+1)
        #pred_tmp.append(line[1])
        #tmp.append(count+1)
        #tmp.append(line[0])
        pred[count+1].append(line[0])
    #if(len(tmp)>0):
      #print(tmp)
#print(count)
print(pred)
# Out:
# defaultdict(<class 'list'>, {14: ['drunk'], 33: ['bin', '##ge', 'eat'], 59: ['weight', 'gain'], 86: [','], 92: ['add', '##icted'], 95: ['cotton', 'mouth', '.'], 98: ['hurt'], 121: ['ruined', 'my', 'teeth', '.'], 144: ['muscle', 'spa', '##sm', '##s'], 171: ['kn', '##ack', '##ered', 'when'], 185: ['brain', 'turn', 'to', 'm', '##ush'], 193: ['cannot', 'be', 'in', 'the', 'sun', '!'], 214: ['withdrawal'], 241: ['going', 'crazy', '.'], 249: ['back', 'pain', '.'], 254: ['weight', 'gain', '.'], 261: ['murdering', 'my', 'mind'], 293: ['nausea', '&'], 298: ['thinking', 'about', 'food'], 305: ['na', '##use', '##ous'], 370: ['no', 'sleep'], 372: ['r', '##ash', '.'], 394: ['c', '##ra', '##ving'], 413: ['no', 'sleep'], 415: ['sweat', '##in'], 417: ['my', 'appetite'], 446: ['do', '##pa', '##mine', 'levels'], 447: ['shaky', '.'], 449: ['20'], 457: ['gain', 'al', '##ot', 'of', 'weight'], 491: ['descent', 'into', 'madness', '.'], 527: ['d', '##ys', '##lex', '##ic', '.'], 539: ['needles', 'feeling', 'i
# ...

# %%
from collections import defaultdict

count = 0

pred1 = defaultdict(list)

for key,value in pred.items():
  #print(key,value)

  for i in range(len(value)-1,-1,-1):
    tag = 0
    str = ''
    if(value[i].startswith('##')):
      #print(value[i])
      str = value[i-1] + value[i][2:]
      print(str)
      value[i-1] = str
      value[i] = ''
print(pred)
# Out:
# binge
# addicted
# ##sms
# spasms
# ##ackered
# knackered
# mush
# ##useous
# nauseous
# rash
# ##raving
# craving
# sweatin
# ##pamine
# dopamine
# alot
# ##lexic
# ##yslexic
# dyslexic
# sleepies
# ##trep
# strep
# zombieish
# ##sleep
# nosleep
# ##tarded
# retarded
# ...

# %%
from collections import defaultdict

count = 0

pred1 = defaultdict(list)

for key,value in pred.items():
  for i in range(len(value)):
    if(value[i]!=''):
      #print(value[i])
      pred1[key].append(value[i])
print(pred1)
# Out:
# defaultdict(<class 'list'>, {14: ['drunk'], 33: ['binge', 'eat'], 59: ['weight', 'gain'], 86: [','], 92: ['addicted'], 95: ['cotton', 'mouth', '.'], 98: ['hurt'], 121: ['ruined', 'my', 'teeth', '.'], 144: ['muscle', 'spasms'], 171: ['knackered', 'when'], 185: ['brain', 'turn', 'to', 'mush'], 193: ['cannot', 'be', 'in', 'the', 'sun', '!'], 214: ['withdrawal'], 241: ['going', 'crazy', '.'], 249: ['back', 'pain', '.'], 254: ['weight', 'gain', '.'], 261: ['murdering', 'my', 'mind'], 293: ['nausea', '&'], 298: ['thinking', 'about', 'food'], 305: ['nauseous'], 370: ['no', 'sleep'], 372: ['rash', '.'], 394: ['craving'], 413: ['no', 'sleep'], 415: ['sweatin'], 417: ['my', 'appetite'], 446: ['dopamine', 'levels'], 447: ['shaky', '.'], 449: ['20'], 457: ['gain', 'alot', 'of', 'weight'], 491: ['descent', 'into', 'madness', '.'], 527: ['dyslexic', '.'], 539: ['needles', 'feeling', 'in', 'my', 'hands'], 551: ['irrational', '.'], 556: ['hot'], 560: ['appetite'], 590: ['sleepies', ','], 592: ['gain
# ...

# %%
path = '/content/test_order.txt'

with open(path,'r') as f:
  for line in f:
    line = line.replace("data1/test/","")
    line = line.replace(".txt","")
    print(line)
    with open("/content/test_order1.txt",'a') as wf:
      wf.write(line)
# Out:
# 344868335588106241
#
# 542032444313313280
#
# 352324070982950912
#
# 333946677121650688
#
# 463433198106853376
#
# 534743382263074816
#
# 496790398912966656
#
# 341360151468580864
#
# 330435039475167232
#
# 467043574547484672
#
# 505545164900040704
#
# 346752793106862080
#
# 346034497315278848
#
# 332149585260716033
#
# 347133617727733760
#
# 532856609413033985
#
# 341636593972555777
#
# 533978084861820928
#
# 458427291526524928
#
# 340156892628258816
#
# 541019712675512321
#
# 331558974723854337
#
# 453689083382861826
#
# 343108523963588608
#
# 440310242531110912
#
# 327331069269528576
#
# 509522653934551040
#
# 538173513681477632
#
# 455299289531838464
#
# 340301551417561088
#
# 485965079943188480
#
# 328770525478412288
#
# 351413287449141249
#
# 450317060573511680
#
# 495387469819305984
#
# 345840626652295168
#
# 512296580888932352
#
# 352538624887238656
#
# 333823628791672832
#
# 342556853961650176
#
# 333468538314584065
#
# 350487851957370880
#
# 469883949884665856
#
# ...

# %%
path = '/content/test_order1.txt'
path1 = '/content/test_tweets.tsv'

import csv

def findSubStr01(substr, str):
    i=1
    while i > 0:
        index = str.find(substr)   #第一次出现的位置
        #index2=str.find(substr,index+1)  #第二次出现的位置
        #index3=str.find(substr,index2+1)  #第三次出现的位置
        #print(index)
        #print(index2)
        #print(index3)
        i-=1
    return index


with open(path,'r') as f:
  with open(path1,'r') as f1:
    tsvin = csv.reader(f1, delimiter='\t')
    with open('/content/submit.tsv', 'a') as wf:
      tsv_w = csv.writer(wf, delimiter='\t')
      tsv_w.writerow(['tweet_id', 'label', 'start', 'end', 'span'])
      for key,value in pred1.items():
        f.seek(0)
        count = 0
        for line in f:
          count +=1
          if(key==count):
            print(line[:len(line)-1])
            id = line[:len(line)-1]
            print(key,value,id,count)
            f1.seek(0)
            for line1 in tsvin:
              #print(line1)
              if(line1[0]==id):
                print(line1[1])
                for vv in value:
                  index = findSubStr01(vv,line1[1])
                  print(index)
                  tsv_w.writerow([id, 'ADE', index, index+len(vv), vv])

# %%
strs = 'abcd'
for index, ch in enumerate(strs):
    print(index,end=' ')
    print(ch)

# %%
def findSubStr01(substr, str):
    i=1
    while i > 0:
        index = str.find(substr)   #第一次出现的位置
        #index2=str.find(substr,index+1)  #第二次出现的位置
        #index3=str.find(substr,index2+1)  #第三次出现的位置
        #print(index)
        #print(index2)
        #print(index3)
        i-=1
    return index

text = "does cymbalta have the side effect of making someone a habitual liar. that's what i think of one of my class members"
substr = "liar"
index = findSubStr01(substr,text)
end = index + len(substr)
print(index,end)
# Out:
# 64 68

# %% [markdown]
# VOTE

# %%
path = "/content/test.txt"
path1 = "/content/test_predictions1.txt"
path2 = "/content/test_predictions2.txt"
path3 = "/content/test_predictions3.txt"
path4 = "/content/test_predictions4.txt"

test_label = []
test_tmp = []
test_1 = []
with open(path,'r') as f:
  for line in f:
    #if(line=='##\n'):
      #print(line)
      #pred_tmp.append('O')
      #test_1.append('O')
      #continue
    #if(line ==' O\n'):
      #pred_tmp.append('O')
      #test_1.append('O')
      #continue
    if(line!='\n'):
      line = line.strip('\n')
      line = line.split(" ")
      #print(line)
      test_tmp.append(line[1])
      #test_tmp.append('PER')
      test_1.append(line[1])
    if(line=='\n'):
      test_label.append(test_tmp)
      test_tmp = []
print(test_label)

pred_1 = []
pred_label = []
pred_tmp = []
with open(path1,'r') as f1:
  for line in f1:
    #if(line=='##\n'):
      #print(line)
      #continue
    #if(line ==' O\n'):
      #pred_tmp.append('O')
    if(line!='\n'):
      line = line.strip('\n')
      line = line.split(" ")
      #print(line[1])
      pred_tmp.append(line[1])
      #pred_tmp.append('PER')
      pred_1.append(line[1])
    if(line=='\n'):
      pred_label.append(pred_tmp)
      pred_tmp = []
print(pred_label)

pred_2 = []
pred_label2 = []
pred_tmp2 = []
with open(path2,'r') as f2:
  for line in f2:
    #if(line=='##\n'):
      #print(line)
      #continue
    #if(line ==' O\n'):
      #pred_tmp.append('O')
    if(line!='\n'):
      line = line.strip('\n')
      line = line.split(" ")
      #print(line[1])
      pred_tmp2.append(line[1])
      #pred_tmp.append('PER')
      pred_2.append(line[1])
    if(line=='\n'):
      pred_label2.append(pred_tmp2)
      pred_tmp2 = []
print(pred_label2)

pred_3 = []
pred_label3 = []
pred_tmp3 = []
with open(path3,'r') as f3:
  for line in f3:
    #if(line=='##\n'):
      #print(line)
      #continue
    #if(line ==' O\n'):
      #pred_tmp.append('O')
    if(line!='\n'):
      line = line.strip('\n')
      line = line.split(" ")
      #print(line[1])
      pred_tmp3.append(line[1])
      #pred_tmp.append('PER')
      pred_3.append(line[1])
    if(line=='\n'):
      pred_label3.append(pred_tmp3)
      pred_tmp3 = []
print(pred_label3)

pred_4 = []
pred_label4 = []
pred_tmp4 = []
with open(path4,'r') as f4:
  for line in f4:
    #if(line=='##\n'):
      #print(line)
      #continue
    #if(line ==' O\n'):
      #pred_tmp.append('O')
    if(line!='\n'):
      line = line.strip('\n')
      line = line.split(" ")
      #print(line[1])
      pred_tmp4.append(line[1])
      #pred_tmp.append('PER')
      pred_4.append(line[1])
    if(line=='\n'):
      pred_label4.append(pred_tmp4)
      pred_tmp4 = []
print(pred_label4)
# Out:
# [['B-ADE', 'I-ADE', 'I-ADE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'], ['O', 'O', 'O', 'O', 'O', 'O', 'O', 
# ...

# %%
"""for item1 in pred_label:
  for item2 in pred_label2:
    for item3 in pred_label3:
      if(('B-ADE' in item1) or ('B-ADE' in item2) or ('B-ADE' in item3)):
        print(item1)
        print(item2)
        print(item3)
        print("---------------------")"""

print(len(pred_label))
print(len(pred_label2))
print(len(pred_label3))
print(len(pred_label4))
pred_vote = []
for i in range(len(pred_label)):
  if((pred_label[i]!=pred_label2[i]) or (pred_label[i]!=pred_label3[i]) or (pred_label3[i]!=pred_label2[i]) or (pred_label[i]!=pred_label4[i]) or (pred_label2[i]!=pred_label4[i]) or (pred_label3[i]!=pred_label4[i])):
    print(pred_label[i])
    print(pred_label2[i])
    print(pred_label3[i])
    print(pred_label4[i])
    #print("---------------------")
    tmp = []
    for j in range(len(pred_label[i])):
      """if(pred_label[i][j]==pred_label2[i][j] and pred_label[i][j]!=pred_label3[i][j]):
        tmp.append(pred_label[i][j])
      elif(pred_label[i][j]!=pred_label2[i][j] and pred_label2[i][j]==pred_label3[i][j]):
        tmp.append(pred_label2[i][j])
      elif(pred_label[i][j]!=pred_label2[i][j] and pred_label[i][j]==pred_label3[i][j]):
        tmp.append(pred_label[i][j])
      elif(pred_label[i][j]==pred_label2[i][j]==pred_label3[i][j]):
        tmp.append(pred_label[i][j])
      elif(pred_label[i][j]!=pred_label2[i][j]!=pred_label3[i][j]):
        tmp.append(pred_label[i][j])"""
      """if(pred_label[i][j]!=pred_label2[i][j] and pred_label2[i][j]==pred_label3[i][j] and pred_label[i][j]!=pred_label4[i][j] and pred_label4[i][j]!=pred_label2[i][j]):
        tmp.append(pred_label2[i][j])
      elif(pred_label[i][j]!=pred_label2[i][j] and pred_label2[i][j]==pred_label4[i][j] and pred_label[i][j]!=pred_label4[i][j] and pred_label3[i][j]!=pred_label2[i][j]):
        tmp.append(pred_label2[i][j])
      elif(pred_label[i][j]!=pred_label2[i][j] and pred_label2[i][j]!=pred_label4[i][j] and pred_label3[i][j]==pred_label4[i][j] and pred_label[i][j]!=pred_label4[i][j]):
        tmp.append(pred_label3[i][j])
      elif(pred_label[i][j]!=pred_label2[i][j] and pred_label2[i][j]==pred_label4[i][j] and pred_label2[i][j]==pred_label3[i][j]):
        tmp.append(pred_label2[i][j])
      else:
        tmp.append(pred_label[i][j])"""
      if('B-ADE' == pred_label[i][j] or 'I-ADE' ==pred_label[i][j]):
        tmp.append(pred_label[i][j])
      elif('B-ADE' == pred_label2[i][j] or 'I-ADE' ==pred_label2[i][j]):
        tmp.append(pred_label2[i][j])
      elif('B-ADE' == pred_label3[i][j] or 'I-ADE' ==pred_label3[i][j]):
        tmp.append(pred_label3[i][j])
      elif('B-ADE' == pred_label4[i][j] or 'I-ADE' ==pred_label4[i][j]):
        tmp.append(pred_label4[i][j])
      else:
        tmp.append(pred_label[i][j])
    print(tmp)
    print("---------------------")
    pred_vote.append(tmp)
  else:
    pred_vote.append(pred_label[i])
print(len(pred_vote))

from seqeval.metrics import f1_score, precision_score, recall_score, accuracy_score
from seqeval.metrics import classification_report
from seqeval.scheme import IOB2
print(accuracy_score(test_label, pred_vote))
print(precision_score(test_label, pred_vote))
print(recall_score(test_label, pred_vote))
print(f1_score(test_label, pred_vote))
print(f1_score(test_label, pred_vote, mode='relax'))
#classification_report(test_label, pred_label)

#for i in range(72):
  #test_1.

#from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
#print(f1_score(test_1,pred_1,average=None))
#print(accuracy_score(test_1,pred_1))
#print(precision_score(test_1,pred_1,average=None))
#print(recall_score(test_1,pred_1,average=None))
# Out:
# 914
# 914
# 914
# 914
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'B-ADE', 'I-ADE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'B-ADE', 'I-ADE', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ---------------------
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ADE', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ADE', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-ADE', 'O', 'O', 'O', 'O']
# ---------------------
# ...

# %%
# !python /content/SMM4H21ScoreTask1.py /content/ /content/output/ Detection
# Out:
# 2021-03-01 08:42:41,615 root         INFO     -------------------------------------------
# 2021-03-01 08:42:41,616 root         INFO     Pred file:/content/res/submit_validation.tsv, Gold file:/content/ref/spans.tsv
# 2021-03-01 08:42:41,616 root         INFO     Tweet file:/content/ref/tweets.tsv, Output file:/content/output/scores.txt
# 2021-03-01 08:42:41,616 root         INFO     Start scoring
# ---------------: /content/ref/spans.tsv
# ['342138828087234560', 'ADE', '119', '125', 'nerves']
# ['342138828087234560', 'ADE', '126', '139', 'muscle spasms']
# ['342382016030973953', 'ADE', '61', '68', 'gaining']
# ['342382016030973953', 'ADE', '91', '110', 'gain like 50 pounds']
# ['345414697148887041', 'ADE', '118', '134', 'frontal headache']
# ['348207562631557122', 'ADE', '76', '80', 'sick']
# ['348207562631557122', 'ADE', '107', '115', 'migraine']
# ['348207562631557122', 'ADE', '117', '121', 'puke']
# ['348207562631557122', 'ADE', '123', '129', 'shakes']
# ...

# %%
import csv
import codecs

path = "/content/submit_validation.tsv"
#wpath = "/content/data1/train/"

with codecs.open(path,'r',encoding='utf-8',errors='ignore') as tsvin:
  tsvin = csv.reader(tsvin, delimiter='\t')
  #with codecs.open('/content/submit_validation11.tsv', 'w', encoding='utf-8',errors='ignore') as f:
    #tsv_w = csv.writer(f, delimiter='\t')
  for line in tsvin:
      #tsv_w.writerow(line)
      print(line)

# %% [markdown]
# 改格式，bio到ann

# %%
path = "/content/train.txt"
dir = "/content/train"
i = 0
with open(path,"r") as f:
  text = f.readlines()
  for line in text:
    if(line!="\n"):
      new_line = str(line).strip("\n").replace(" B-"," ").replace(" I-"," ").split(" ")
      #print(new_line)
      path1 = dir + "/" + str(i) + ".txt"
      with open(path1,"a") as wf:
        wf.write(new_line[0]+" "+new_line[-1]+"\n")
    elif(line=="\n"):
      i = i+1

# %%
# !rm -r /content/dev

# %%
# !mkdir /content/dev

# %% [markdown]
# 重新写个方法呢

# %%
import os

#path = "/content/converted_Alexis224_new.tsv"
path = "/content/train"
path1 = "/content/data1/train"

for file in os.listdir(path):
  #print(file[:6])
  with open(path + "/" + file, "r") as f:
    word_lst = []
    tag_count = 0
    text = f.readlines()
    for line in text:
      new_line = line.strip("\n").split(" ")
      #print(new_line)
      if(new_line[1]=="O"):
        word_lst.append(new_line[0])
      elif(new_line[1]!="O"):
        tag_count += 1
        start = len(word_lst) + 1
        for i in range(len(word_lst)):
          start += len(word_lst[i])
        word_lst.append(new_line[0])
        end = start + len(new_line[0])
        #print(word_lst)
        #print(start,end)
        with open(path1 + "/" + "train_" + file[:-4] + ".ann", "a") as wf:
          wf.write(file[:-4] + "\t" + new_line[1] + " " + str(start) + ";" + str(end) + "\t" + new_line[0] + "\n")
    #print(tag_count)
    if(tag_count==0):
      with open(path1 + "/" + "train_" + file[:-4] + ".ann", "a") as wf:
        wf.write("#")

# %%
# !rm -r /content/dev_ann/

# %%
# !mkdir /content/dev_ann/

# %%
path = "/content/train"
path1 = "/content/data1/train"

for file in os.listdir(path):
  #print(file[:6])
  with open(path + "/" + file, "r") as f:
    word_lst = []
    tag_count = 0
    text = f.readlines()
    for line in text:
      new_line = line.strip("\n").split(" ")
      with open(path1 + "/" + "train_" + file, "a") as wf:
        wf.write(new_line[0] + "\n")

# %%
# !rm -r /content/data1/train

# %%
# !mkdir /content/data1/train

# %%
# !rm -r /content/train

# %%
# !mkdir /content/train

# %%
# !rm -r /content/dev

# %%
# !mkdir /content/dev

# %%
# !rm -r /content/test

# %%
# !mkdir /content/test

# %%
# !rm -r /content/train

# %%
# !tar xzvf /content/data1/test/test_ann.tar.gz

# %%
# !rm /content/train.txt

# %% [markdown]
# i2b2 format

# %%
# !unzip /content/ehr_format.zip

# %%
path = "/content/hhh"
path1 = "/content/data2/train"
import os

for file in os.listdir(path):
  with open(path + "/" + file, "r") as f:
    if(file.endswith(".ann")):
      text = f.readlines()
      for line in text:
        new_line = line.strip("\n").split("\t")
        #print(new_line)
        with open(path1 + "/" + file, "a") as wf:
          wf.write(new_line[0] + "\t" + new_line[1] + " " + str(new_line[2]).replace(" ",";") + "\t" + new_line[3] + "\n")
    else:
      text = f.readlines()
      for line in text:
        with open(path1 + "/" + file, "a") as wf:
          wf.write(line)

# %%
path = "/content/ehr_format/train"

for file in os.listdir(path):
  with open(path + "/" + file, "r") as f:
    if(file.endswith(".ann")):
      text = f.readlines()
      for line in text:
        if(line!="\n"):
          new_line = line.strip("\n").split("\t")
          #print(line)
          if(str(new_line[1]).endswith("SOCIAL SECURITY NUMBER")):
            print(file)
